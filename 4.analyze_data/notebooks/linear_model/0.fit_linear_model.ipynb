# %% [markdown]
# ## Fit a linear model on cell morphology features
#
# We aim to determine which features are significantly impacted by drug treatment, adjusted by cell count.

# %%
import pathlib
import pandas as pd

from sklearn.linear_model import LinearRegression

from pycytominer import feature_select
from pycytominer.cyto_utils import infer_cp_features

# %%
# Define inputs and outputs
plate = "localhost220513100001_KK22-05-198_FactinAdjusted"  # Focusing on plate 2
file_suffix = "_sc_norm_fs_cellprofiler_ic.csv.gz"

data_dir = pathlib.Path("..", "..", "..", "3.process_cfret_features", "data")

cp_file = pathlib.Path(data_dir, f"{plate}{file_suffix}")

output_dir = pathlib.Path("results")
output_cp_file = pathlib.Path(output_dir, f"{plate}_linear_model_cp_features.tsv")

# %%
# Load data
cp_df = pd.read_csv(cp_file)

# Drop NA columns
cp_df = feature_select(
    cp_df,
    operation="drop_na_columns",
    na_cutoff=0
)

# Count number of cells per well and add to dataframe as metadata
cell_count_df = pd.DataFrame(
    cp_df.groupby("Metadata_Well").count()["Metadata_treatment"]
).reset_index()
cell_count_df.columns = ["Metadata_Well", "Metadata_cell_count_per_well"]
cp_df = cell_count_df.merge(cp_df, on=["Metadata_Well"])

# Clean the dose column to extract numeric value
cp_df = cp_df.assign(Metadata_dose_numeric=cp_df.Metadata_dose.str.strip("uM").astype(float))

# Define CellProfiler features
cp_features = infer_cp_features(cp_df)

print(f"We are testing {len(cp_features)} CellProfiler features")
print(cp_df.shape)
cp_df.head()
# Out:
# We are testing 505 CellProfiler features
# (17995, 521)
#   Metadata_Well  Metadata_cell_count_per_well  Unnamed: 0 Metadata_WellRow  \
# 0           A09                           357           0                A
# 1           A09                           357           1                A
# 2           A09                           357           2                A
# 3           A09                           357           3                A
# 4           A09                           357           4                A
#
#    Metadata_WellCol  Metadata_number_of_singlecells  Metadata_heart_number  \
# 0                 9                             357                      9
# 1                 9                             357                      9
# 2                 9                             357                      9
# 3                 9                             357                      9
# 4                 9                             357                      9
#
#   Metadata_treatment Metadata_dose  Metadata_ImageNumber  ...  \
# 0             drug_x           5uM                     1  ...
# 1             drug_x           5uM                     1  ...
# 2             drug_x           5uM                     1  ...
# 3             drug_x           5uM                     1  ...
# 4             drug_x           5uM                     1  ...
#
#   Nuclei_Texture_InverseDifferenceMoment_PM_3_03_256  \
# 0                                          -0.889765
# 1                                           0.177754
# 2                                          -1.693589
# 3                                          -1.901882
# 4                                          -0.113685
#
#    Nuclei_Texture_SumEntropy_ER_3_03_256  \
# 0                               0.584458
# 1                              -1.035615
# 2                               0.386622
# 3                               1.253318
# 4                              -0.535773
#
#    Nuclei_Texture_SumEntropy_Hoechst_3_00_256  \
# 0                                   -0.756811
# 1                                   -0.488188
# 2                                    0.999544
# 3                                    0.376866
# 4                                   -0.974978
#
#    Nuclei_Texture_SumEntropy_Mitochondria_3_03_256  \
# 0                                         1.646285
# 1                                        -0.927906
# 2                                         1.192634
# 3                                         1.911982
# 4                                        -0.045518
#
#    Nuclei_Texture_SumEntropy_PM_3_01_256  \
# 0                               1.627744
# 1                              -0.378530
# 2                               1.117077
# 3                               1.972299
# 4                               0.206396
#
#    Nuclei_Texture_SumVariance_ER_3_03_256  \
# 0                               -0.130277
# 1                               -0.452070
# 2                               -0.112725
# 3                                1.347963
# 4                               -0.412969
#
#    Nuclei_Texture_SumVariance_Hoechst_3_01_256  \
# 0                                    -0.329540
# 1                                    -0.309250
# 2                                     0.048069
# 3                                    -0.199487
# 4                                    -0.336288
#
#    Nuclei_Texture_SumVariance_Mitochondria_3_03_256  \
# 0                                          0.168744
# 1                                         -0.179711
# 2                                         -0.020985
# 3                                          0.628766
# 4                                         -0.155509
#
#    Nuclei_Texture_SumVariance_PM_3_01_256  Metadata_dose_numeric
# 0                                0.223935                    5.0
# 1                               -0.193299                    5.0
# 2                                0.010248                    5.0
# 3                                0.704861                    5.0
# 4                               -0.156673                    5.0
#
# [5 rows x 521 columns]

# %% [markdown]
# ## Fit linear model

# %%
# Setup linear modeling framework
variables = ["Metadata_cell_count_per_well", "Metadata_dose_numeric"]
X = cp_df.loc[:, variables]

print(X.shape)
X.head()
# Out:
# (17995, 2)
#    Metadata_cell_count_per_well  Metadata_dose_numeric
# 0                           357                    5.0
# 1                           357                    5.0
# 2                           357                    5.0
# 3                           357                    5.0
# 4                           357                    5.0

# %%
# Fit linear model for each feature
lm_results = []
for cp_feature in cp_features:
    # Subset CP data to each individual feature (univariate test)
    cp_subset_df = cp_df.loc[:, cp_feature]

    # Fit linear model
    lm = LinearRegression(fit_intercept=True)
    lm_result = lm.fit(X=X, y=cp_subset_df)
    
    # Extract Beta coefficients
    # (contribution of feature to X covariates)
    coef = lm_result.coef_
    
    # Estimate fit (R^2)
    r2_score = lm.score(X=X, y=cp_subset_df)
    
    # Add results to a growing list
    lm_results.append([cp_feature, r2_score] + list(coef))

# Convert results to a pandas DataFrame
lm_results = pd.DataFrame(
    lm_results,
    columns=["feature", "r2_score", "cell_count_coef", "treatment_dose_coef"]
)

# Output file
lm_results.to_csv(output_cp_file, sep="\t", index=False)

print(lm_results.shape)
lm_results.head()
# Out:
# (505, 4)
#                                feature  r2_score  cell_count_coef  \
# 0      Cytoplasm_AreaShape_Compactness  0.026470         0.000403
# 1       Cytoplasm_AreaShape_FormFactor  0.070085        -0.000828
# 2  Cytoplasm_AreaShape_MajorAxisLength  0.059390        -0.001345
# 3  Cytoplasm_AreaShape_MinorAxisLength  0.061127        -0.001351
# 4      Cytoplasm_AreaShape_Orientation  0.000086         0.000006
#
#    treatment_dose_coef
# 0            -0.050196
# 1             0.074347
# 2             0.025609
# 3             0.027655
# 4             0.003491
